# %%
import glob
import pandas as pd
from collections import defaultdict
from itertools import chain, combinations

# Укажите путь к вашим CSV-файлам (например, если они находятся в папке "data")
#all_files = glob.glob(r'C:\Users\Гребенников Матвей\Desktop\Диплом\Диплом\GeneratedLabelledFlows\TrafficLabelling/*.csv')

# Читаем все файлы в список DataFrame
#df_list = [pd.read_csv(file, encoding='cp1252', low_memory=False) for file in all_files]


# Объединяем все DataFrame в один общий DataFrame
#combined_df = pd.concat(df_list, ignore_index=True)

# Удаляем лишние пробелы в названиях столбцов
#combined_df.columns = combined_df.columns.str.strip()

# Теперь combined_df можно использовать для предобработки

def preprocess_data(df):
    """
    Преобразует DataFrame в список транзакций.
    Каждая транзакция – это список строк вида "ИмяСтолбца:Значение".
    Используются столбцы: Timestamp, Source IP, Source Port, Destination IP, 
    Destination Port, Protocol, Label.
    """
    transactions = []
    selected_columns = [ 'Total Fwd Packets','Flow Duration', 'Destination Port', 'Protocol', 'Label']
    for index, row in df.iterrows():
        transaction = []
        for col in selected_columns:
            value = str(row[col])
            item = f"{col}:{value}"
            transaction.append(item)
        transactions.append(transaction)
    return transactions

# Используем объединённый DataFrame для формирования транзакций
#transactions = preprocess_data(combined_df)

# %%
# Класс узла FP-дерева
class FPNode:
    def __init__(self, item, count, parent):
        self.item = item          # Например, "Protocol:TCP"
        self.count = count        # Подсчет вхождений
        self.parent = parent      # Родительский узел
        self.children = {}        # Дочерние узлы: {элемент: FPNode}
        self.node_link = None     # Ссылка на следующий узел с таким же элементом

    def increment(self, count):
        self.count += count

def update_tree(items, tree, header_table, count):
    """
    Рекурсивно добавляет отсортированный список элементов в FP-дерево.
    Если элемент уже присутствует – увеличивает его счётчик, иначе создаёт новый узел.
    """
    first_item = items[0]
    if first_item in tree.children:
        tree.children[first_item].increment(count)
    else:
        new_node = FPNode(first_item, count, tree)
        tree.children[first_item] = new_node
        # Обновляем заголовочную таблицу: если узел отсутствует, записываем его,
        # иначе добавляем в цепочку через node_link.
        if header_table[first_item][1] is None:
            header_table[first_item][1] = new_node
        else:
            current = header_table[first_item][1]
            while current.node_link is not None:
                current = current.node_link
            current.node_link = new_node
    if len(items) > 1:
        update_tree(items[1:], tree.children[first_item], header_table, count)

def create_fp_tree(transactions, min_support):
    """
    Создает FP-дерево из транзакций:
      1. Подсчитывает поддержку каждого элемента.
      2. Отбрасывает элементы с поддержкой ниже min_support.
      3. Формирует заголовочную таблицу: {элемент: [поддержка, ссылка на первый узел]}.
      4. Для каждой транзакции оставляет только частые элементы, сортирует их по убыванию поддержки 
         и рекурсивно добавляет в дерево.
    """
    freq = {}
    for transaction in transactions:
        for item in transaction:
            freq[item] = freq.get(item, 0) + 1
    freq = {item: count for item, count in freq.items() if count >= min_support}
    if not freq:
        return None, None
    header_table = {item: [count, None] for item, count in freq.items()}
    root = FPNode('Null', 1, None)
    for transaction in transactions:
        transaction_items = [item for item in transaction if item in freq]
        if transaction_items:
            sorted_items = sorted(transaction_items, key=lambda item: header_table[item][0], reverse=True)
            update_tree(sorted_items, root, header_table, 1)
    return root, header_table

def ascend_fp_tree(node):
    """
    Поднимается по дереву от узла до корня (не включая корень)
    и возвращает список элементов пути.
    """
    path = []
    while node.parent is not None and node.parent.item != 'Null':
        node = node.parent
        path.append(node.item)
    return path

def find_prefix_paths(base_item, header_table):
    """
    Находит условную базу (prefix pattern base) для base_item.
    Возвращает словарь: {frozenset(пути): count}
    """
    conditional_patterns = {}
    node = header_table[base_item][1]
    while node:
        prefix_path = ascend_fp_tree(node)
        if prefix_path:
            conditional_patterns[frozenset(prefix_path)] = node.count
        node = node.node_link
    return conditional_patterns

def mine_fp_tree(tree, header_table, min_support, pre_fix, frequent_itemsets):
    """
    Рекурсивно добывает частые наборы элементов из FP-дерева.
    """
    sorted_items = sorted(header_table.items(), key=lambda x: x[1][0])
    for base_item, base_info in sorted_items:
        new_freq_set = pre_fix.copy()
        new_freq_set.add(base_item)
        frequent_itemsets[frozenset(new_freq_set)] = base_info[0]
        conditional_patterns = find_prefix_paths(base_item, header_table)
        conditional_transactions = []
        for path, count in conditional_patterns.items():
            for _ in range(count):
                conditional_transactions.append(list(path))
        if conditional_transactions:
            conditional_tree, conditional_header = create_fp_tree(conditional_transactions, min_support)
            if conditional_header is not None:
                mine_fp_tree(conditional_tree, conditional_header, min_support, new_freq_set, frequent_itemsets)

# %%
def generate_association_rules(frequent_itemsets, min_conf):
    """
    Для каждого частого набора генерирует правила A -> B, 
    но оставляет только те, в которых B состоит исключительно из меток (Label:...).
    Рассчитывает достоверность: conf = support(A ∪ B) / support(A)
    Если conf >= min_conf, правило добавляется.
    """
    rules = []
    for itemset in frequent_itemsets:
        if len(itemset) < 2:
            continue
        # Перебираем все непустые подмножества itemset
        for subset in chain.from_iterable(combinations(itemset, r) for r in range(1, len(itemset))):
            A = set(subset)
            B = set(itemset) - A
            # Ограничиваем правила: оставляем только те, где все элементы B начинаются с "Label:"
            if B and all(item.startswith("Label:") for item in B) and frozenset(A) in frequent_itemsets:
                conf = frequent_itemsets[frozenset(itemset)] / frequent_itemsets[frozenset(A)]
                if conf >= min_conf:
                    rules.append((A, B, conf, frequent_itemsets[frozenset(itemset)]))
    return rules


def improved_fp_growth(transactions, min_sup, min_conf):
    """
    Улучшенный FP-growth объединяет:
      - Построение FP-дерева.
      - Добычу частых наборов (mine_fp_tree).
      - Генерацию ассоциативных правил.
    Возвращает frequent_itemsets и правила.
    """
    fp_tree, header_table = create_fp_tree(transactions, min_sup)
    frequent_itemsets = {}
    if fp_tree:
        mine_fp_tree(fp_tree, header_table, min_sup, set(), frequent_itemsets)
    rules = generate_association_rules(frequent_itemsets, min_conf)
    return frequent_itemsets, rules

# %%
# Для COFI‑дерева создаём отдельные классы и функции, чтобы не было конфликта с FP-деревом.

class COFINode:
    def __init__(self, item, count, parent):
        self.item = item                # Например, "Protocol:6"
        self.count = count              # Подсчет вхождений
        self.parent = parent            # Родительский узел
        self.children = {}              # Дочерние узлы: {элемент: COFINode}
        self.node_link = None           # Ссылка на следующий узел с таким же элементом
        self.participation_counter = 0  # Дополнительный счетчик (при необходимости)

    def increment(self, count):
        self.count += count

def update_cofi_tree(items, tree, header_table, count):
    first_item = items[0]
    if first_item in tree.children:
        tree.children[first_item].increment(count)
    else:
        new_node = COFINode(first_item, count, tree)
        tree.children[first_item] = new_node
        if header_table[first_item][1] is None:
            header_table[first_item][1] = new_node
        else:
            current = header_table[first_item][1]
            while current.node_link:
                current = current.node_link
            current.node_link = new_node
    if len(items) > 1:
        update_cofi_tree(items[1:], tree.children[first_item], header_table, count)

def create_cofi_tree_cofi(transactions, min_support):
    """
    Создает COFI‑дерево из транзакций (отдельная функция для COFI‑дерева).
    """
    freq = {}
    for transaction in transactions:
        for item in transaction:
            freq[item] = freq.get(item, 0) + 1
    freq = {item: count for item, count in freq.items() if count >= min_support}
    if not freq:
        return None, None
    header_table = {item: [count, None] for item, count in freq.items()}
    root = COFINode('Null', 1, None)
    for transaction in transactions:
        transaction_items = [item for item in transaction if item in freq]
        if transaction_items:
            sorted_items = sorted(transaction_items, key=lambda item: header_table[item][0], reverse=True)
            update_cofi_tree(sorted_items, root, header_table, 1)
    return root, header_table

def build_cofi_tree_for_item(base_item, fp_header, min_support):
    """
    Извлекает условную базу (prefix pattern base) для base_item из FP-дерева
    и строит COFI‑дерево для этих транзакций.
    """
    conditional_patterns = find_prefix_paths(base_item, fp_header)
    cofi_transactions = []
    for path, count in conditional_patterns.items():
        for _ in range(count):
            cofi_transactions.append(list(path))
    return create_cofi_tree_cofi(cofi_transactions, min_support)

def mine_cofi_tree(tree, header_table, min_support, pre_fix, cofi_patterns):
    """
    Рекурсивно добывает частые наборы элементов из COFI‑дерева.
    """
    sorted_items = sorted(header_table.items(), key=lambda x: x[1][0])
    for base_item, base_info in sorted_items:
        new_freq_set = pre_fix.copy()
        new_freq_set.add(base_item)
        cofi_patterns[frozenset(new_freq_set)] = base_info[0]
        conditional_patterns = find_prefix_paths(base_item, header_table)
        conditional_transactions = []
        for path, count in conditional_patterns.items():
            for _ in range(count):
                conditional_transactions.append(list(path))
        if conditional_transactions:
            conditional_tree, conditional_header = create_cofi_tree_cofi(conditional_transactions, min_support)
            if conditional_header is not None:
                mine_cofi_tree(conditional_tree, conditional_header, min_support, new_freq_set, cofi_patterns)

def build_sd_structure(cofi_patterns, min_support):
    """
    Группирует наборы из COFI‑дерева по длине и корректирует их поддержку.
    Для каждого набора меньшей длины ищутся наборы с большей длиной, содержащие его,
    и поддержка увеличивается.
    """
    sd_segments = {}
    for pattern, support in cofi_patterns.items():
        length = len(pattern)
        sd_segments.setdefault(length, []).append((pattern, support))
    
    updated_patterns = {}
    for length in sorted(sd_segments.keys()):
        for pattern, support in sd_segments[length]:
            updated_support = support
            for longer_length in sorted(sd_segments.keys()):
                if longer_length > length:
                    for longer_pattern, longer_support in sd_segments[longer_length]:
                        if pattern.issubset(longer_pattern):
                            updated_support += longer_support
            updated_patterns[pattern] = updated_support
    
    final_patterns = {pattern: sup for pattern, sup in updated_patterns.items() if sup >= min_support}
    return final_patterns

# %%
# Загрузка данных CICIDS 2017 и предобработка
#transactions = preprocess_data(combined_df)

df = pd.read_csv(r'C:\Users\Гребенников Матвей\Desktop\Диплом\Диплом\GeneratedLabelledFlows\TrafficLabelling\Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv')
df.columns = df.columns.str.strip()
transactions = preprocess_data(df)

# Задаем параметры: минимальный порог поддержки и достоверности
min_support = 10
min_conf = 0.8

# 1. Построение FP-дерева (MDFP) и добыча частых наборов
fp_tree, header_table = create_fp_tree(transactions, min_support)
frequent_itemsets = {}
if fp_tree is None:
    print("Нет частых элементов, удовлетворяющих min_support.")
else:
    mine_fp_tree(fp_tree, header_table, min_support, set(), frequent_itemsets)
    print("Частые наборы (MDFP):")
    for itemset, support in sorted(frequent_itemsets.items(), key=lambda x: x[1], reverse=True):
        print(set(itemset), "поддержка:", support)

    # 2. Улучшенный FP-growth (объединяет этапы из 4.3)
    freq_itemsets_improved, association_rules = improved_fp_growth(transactions, min_support, min_conf)
    print("\nЧастые наборы (улучшенный FP-growth):")
    for itemset, support in sorted(freq_itemsets_improved.items(), key=lambda x: x[1], reverse=True):
        print(set(itemset), "поддержка:", support)
        
    print("\nАссоциативные правила (min_conf = {}):".format(min_conf))
    for A, B, conf, sup in association_rules:
        print(f"{A} -> {B} (conf: {conf:.2f}, support: {sup})")
    

 # 3. Применение COFI-дерева и структуры SD:
    # Используем несколько базовых элементов 
    base_items = [
    "Label:BENIGN",
    "Label:DDoS",            # если есть такие метки
    "Label:PortScan",       # если есть такие метки
    "Protocol:6",           # TCP
    "Protocol:17",          # UDP
    "Destination Port:80",
    "Destination Port:443",
    "Destination Port:53",
    "Protocol:6",
    "Protocol:17",
    "Protocol:1"
                 ]
    all_cofi_patterns = {}
    for base_item in base_items:
        if base_item in header_table:
            # Строим COFI-дерево по транзакциям, где содержится base_item
            cofi_tree, cofi_header = create_cofi_tree_cofi([t for t in transactions if base_item in t], min_support)
            if cofi_tree and cofi_header:
                cofi_patterns = {}
                mine_cofi_tree(cofi_tree, cofi_header, min_support, pre_fix=set([base_item]), cofi_patterns=cofi_patterns)
                print(f"\nЧастые наборы из COFI-дерева для {base_item}:")
                for itemset, support in sorted(cofi_patterns.items(), key=lambda x: x[1], reverse=True):
                    print(set(itemset), "поддержка:", support)
                all_cofi_patterns.update(cofi_patterns)
            else:
                print(f"\nНет условных транзакций для {base_item} с min_support = {min_support}.")
        else:
            print(f"\nЭлемент {base_item} не найден в FP-дереве.")
    
    print("\n--- Применение структуры SD ко всем полученным наборам ---")
    sd_patterns = build_sd_structure(all_cofi_patterns, min_support)
    for pattern, support in sorted(sd_patterns.items(), key=lambda x: x[1], reverse=True):
        print(set(pattern), "поддержка:", support)
# Out:
# Частые наборы (MDFP):
# {'Protocol:6'} поддержка: 192820
# {'Destination Port:80'} поддержка: 136951
# {'Protocol:6', 'Destination Port:80'} поддержка: 136951
# {'Label:DDoS'} поддержка: 128027
# {'Protocol:6', 'Label:DDoS'} поддержка: 128027
# {'Destination Port:80', 'Label:DDoS'} поддержка: 128024
# {'Protocol:6', 'Destination Port:80', 'Label:DDoS'} поддержка: 128024
# {'Label:BENIGN'} поддержка: 97718
# {'Protocol:6', 'Label:BENIGN'} поддержка: 64793
# {'Total Fwd Packets:3'} поддержка: 61938
# {'Protocol:6', 'Total Fwd Packets:3'} поддержка: 61883
# {'Total Fwd Packets:3', 'Destination Port:80'} поддержка: 59579
# {'Protocol:6', 'Total Fwd Packets:3', 'Destination Port:80'} поддержка: 59579
# {'Total Fwd Packets:3', 'Label:DDoS'} поддержка: 56728
# {'Protocol:6', 'Total Fwd Packets:3', 'Label:DDoS'} поддержка: 56728
# {'Destination Port:80', 'Total Fwd Packets:3', 'Label:DDoS'} поддержка: 56728
# {'Protocol:6', 'Destination Port:80', 'Total Fwd Packets:3', 'Label:DDoS'} поддержка: 56728
# {'Protocol:17'} поддержка: 32871
# {'Label:BENIGN', 'Protocol:17'} поддержка: 32871
# {'Destination Port:53'} поддержка: 31950
# {'Label:BENIGN', 'Destination Port:53'} поддержка: 31950
# {'Protocol:17', 'Destination Port:53'} поддержка: 31950
# {'Label:BENIGN', 'Protocol:17', 'Destination Port:53'} поддержка: 31950
# {'Total Fwd Packets:1'} поддержка: 31124
# {'Label:BENIGN', 'Total Fwd Packets:1'} поддержка: 31077
# {'Total Fwd Packets:2'} поддержка: 30689
# {'Label:BENIGN', 'Total Fwd Packets:2'} поддержка: 29236
# {'Total Fwd Packets:5'} поддержка: 27128
# {'Protocol:6', 'Total Fwd Packets:5'} поддержка: 27128
# {'Total Fwd Packets:4'} поддержка: 27053
# {'Protocol:6', 'Total Fwd Packets:4'} поддержка: 23979
# {'Total Fwd Packets:4', 'Destination Port:80'} поддержка: 23494
# {'Protocol:6', 'Total Fwd Packets:4', 'Destination Port:80'} поддержка: 23494
# {'Total Fwd Packets:4', 'Label:DDoS'} поддержка: 23180
# {'Protocol:6', 'Total Fwd Packets:4', 'Label:DDoS'} поддержка: 23180
# {'Total Fwd Packets:4', 'Destination Port:80', 'Label:DDoS'} поддержка: 23180
# {'Protocol:6', 'Total Fwd Packets:4', 'Destination Port:80', 'Label:DDoS'} поддержка: 23180
# {'Protocol:6', 'Total Fwd Packets:1'} поддержка: 23100
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:1'} поддержка: 23053
# {'Total Fwd Packets:5', 'Destination Port:80'} поддержка: 22471
# {'Protocol:6', 'Total Fwd Packets:5', 'Destination Port:80'} поддержка: 22471
# {'Total Fwd Packets:5', 'Label:DDoS'} поддержка: 22301
# {'Protocol:6', 'Total Fwd Packets:5', 'Label:DDoS'} поддержка: 22301
# {'Total Fwd Packets:5', 'Destination Port:80', 'Label:DDoS'} поддержка: 22301
# {'Protocol:6', 'Total Fwd Packets:5', 'Destination Port:80', 'Label:DDoS'} поддержка: 22301
# {'Total Fwd Packets:2', 'Protocol:17'} поддержка: 21382
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Protocol:17'} поддержка: 21382
# {'Total Fwd Packets:2', 'Destination Port:53'} поддержка: 20995
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Destination Port:53'} поддержка: 20995
# {'Total Fwd Packets:2', 'Protocol:17', 'Destination Port:53'} поддержка: 20995
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Protocol:17', 'Destination Port:53'} поддержка: 20995
# {'Total Fwd Packets:8'} поддержка: 19809
# {'Protocol:6', 'Total Fwd Packets:8'} поддержка: 19795
# {'Total Fwd Packets:8', 'Destination Port:80'} поддержка: 18215
# {'Protocol:6', 'Total Fwd Packets:8', 'Destination Port:80'} поддержка: 18215
# {'Total Fwd Packets:8', 'Label:DDoS'} поддержка: 18067
# {'Protocol:6', 'Total Fwd Packets:8', 'Label:DDoS'} поддержка: 18067
# {'Destination Port:80', 'Total Fwd Packets:8', 'Label:DDoS'} поддержка: 18067
# {'Protocol:6', 'Destination Port:80', 'Total Fwd Packets:8', 'Label:DDoS'} поддержка: 18067
# {'Destination Port:443'} поддержка: 13485
# {'Label:BENIGN', 'Destination Port:443'} поддержка: 13485
# {'Protocol:6', 'Destination Port:443'} поддержка: 13485
# {'Protocol:6', 'Total Fwd Packets:2'} поддержка: 9305
# {'Label:BENIGN', 'Destination Port:80'} поддержка: 8927
# {'Protocol:6', 'Label:BENIGN', 'Destination Port:80'} поддержка: 8927
# {'Total Fwd Packets:1', 'Protocol:17'} поддержка: 8024
# {'Label:BENIGN', 'Total Fwd Packets:1', 'Protocol:17'} поддержка: 8024
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN'} поддержка: 7852
# {'Total Fwd Packets:1', 'Destination Port:53'} поддержка: 7758
# {'Label:BENIGN', 'Total Fwd Packets:1', 'Destination Port:53'} поддержка: 7758
# {'Protocol:17', 'Total Fwd Packets:1', 'Destination Port:53'} поддержка: 7758
# {'Protocol:17', 'Label:BENIGN', 'Total Fwd Packets:1', 'Destination Port:53'} поддержка: 7758
# {'Total Fwd Packets:6'} поддержка: 7703
# {'Protocol:6', 'Total Fwd Packets:6'} поддержка: 7620
# {'Label:BENIGN', 'Total Fwd Packets:6'} поддержка: 6514
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:6'} поддержка: 6431
# {'Total Fwd Packets:7'} поддержка: 6272
# {'Protocol:6', 'Total Fwd Packets:7'} поддержка: 6272
# {'Total Fwd Packets:9'} поддержка: 5324
# {'Protocol:6', 'Total Fwd Packets:9'} поддержка: 5324
# {'Total Fwd Packets:7', 'Label:BENIGN'} поддержка: 5271
# {'Protocol:6', 'Total Fwd Packets:7', 'Label:BENIGN'} поддержка: 5271
# {'Label:BENIGN', 'Total Fwd Packets:3'} поддержка: 5210
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:3'} поддержка: 5155
# {'Label:BENIGN', 'Total Fwd Packets:5'} поддержка: 4827
# {'Label:BENIGN', 'Protocol:6', 'Total Fwd Packets:5'} поддержка: 4827
# {'Total Fwd Packets:9', 'Destination Port:80'} поддержка: 4264
# {'Protocol:6', 'Total Fwd Packets:9', 'Destination Port:80'} поддержка: 4264
# {'Total Fwd Packets:9', 'Label:DDoS'} поддержка: 4057
# {'Protocol:6', 'Total Fwd Packets:9', 'Label:DDoS'} поддержка: 4057
# {'Total Fwd Packets:9', 'Destination Port:80', 'Label:DDoS'} поддержка: 4057
# {'Protocol:6', 'Total Fwd Packets:9', 'Destination Port:80', 'Label:DDoS'} поддержка: 4057
# {'Label:BENIGN', 'Total Fwd Packets:4'} поддержка: 3873
# {'Total Fwd Packets:2', 'Destination Port:80'} поддержка: 3488
# {'Protocol:6', 'Total Fwd Packets:2', 'Destination Port:80'} поддержка: 3488
# {'Total Fwd Packets:4', 'Protocol:17'} поддержка: 3067
# {'Label:BENIGN', 'Total Fwd Packets:4', 'Protocol:17'} поддержка: 3067
# {'Total Fwd Packets:4', 'Destination Port:53'} поддержка: 3065
# {'Label:BENIGN', 'Total Fwd Packets:4', 'Destination Port:53'} поддержка: 3065
# {'Total Fwd Packets:4', 'Protocol:17', 'Destination Port:53'} поддержка: 3065
# {'Label:BENIGN', 'Total Fwd Packets:4', 'Protocol:17', 'Destination Port:53'} поддержка: 3065
# {'Label:BENIGN', 'Protocol:6', 'Destination Port:443'} поддержка: 3004
# {'Label:BENIGN', 'Total Fwd Packets:3', 'Destination Port:80'} поддержка: 2851
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:3', 'Destination Port:80'} поддержка: 2851
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Destination Port:80'} поддержка: 2035
# {'Label:BENIGN', 'Protocol:6', 'Total Fwd Packets:2', 'Destination Port:80'} поддержка: 2035
# {'Total Fwd Packets:2', 'Destination Port:443'} поддержка: 1972
# {'Protocol:6', 'Total Fwd Packets:2', 'Destination Port:443'} поддержка: 1972
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Destination Port:443'} поддержка: 1972
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Destination Port:443', 'Protocol:6'} поддержка: 1972
# {'Label:BENIGN', 'Total Fwd Packets:8'} поддержка: 1742
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:8'} поддержка: 1728
# {'Total Fwd Packets:2', 'Label:DDoS'} поддержка: 1453
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:DDoS'} поддержка: 1453
# {'Total Fwd Packets:2', 'Destination Port:80', 'Label:DDoS'} поддержка: 1453
# {'Protocol:6', 'Total Fwd Packets:2', 'Destination Port:80', 'Label:DDoS'} поддержка: 1453
# {'Total Fwd Packets:6', 'Destination Port:80'} поддержка: 1401
# {'Protocol:6', 'Total Fwd Packets:6', 'Destination Port:80'} поддержка: 1401
# {'Flow Duration:3'} поддержка: 1342
# {'Label:BENIGN', 'Flow Duration:3'} поддержка: 1341
# {'Protocol:6', 'Flow Duration:3'} поддержка: 1290
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:3'} поддержка: 1289
# {'Total Fwd Packets:2', 'Flow Duration:3'} поддержка: 1279
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:3'} поддержка: 1279
# {'Total Fwd Packets:9', 'Label:BENIGN'} поддержка: 1267
# {'Protocol:6', 'Total Fwd Packets:9', 'Label:BENIGN'} поддержка: 1267
# {'Protocol:6', 'Total Fwd Packets:2', 'Flow Duration:3'} поддержка: 1227
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:3'} поддержка: 1227
# {'Total Fwd Packets:6', 'Label:DDoS'} поддержка: 1189
# {'Protocol:6', 'Total Fwd Packets:6', 'Label:DDoS'} поддержка: 1189
# {'Total Fwd Packets:6', 'Destination Port:80', 'Label:DDoS'} поддержка: 1189
# {'Protocol:6', 'Total Fwd Packets:6', 'Destination Port:80', 'Label:DDoS'} поддержка: 1189
# {'Total Fwd Packets:7', 'Destination Port:80'} поддержка: 1141
# {'Protocol:6', 'Total Fwd Packets:7', 'Destination Port:80'} поддержка: 1141
# {'Destination Port:443', 'Total Fwd Packets:8'} поддержка: 1091
# {'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:8'} поддержка: 1091
# {'Label:BENIGN', 'Destination Port:443', 'Total Fwd Packets:8'} поддержка: 1091
# {'Label:BENIGN', 'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:8'} поддержка: 1091
# {'Total Fwd Packets:9', 'Destination Port:443'} поддержка: 1005
# {'Protocol:6', 'Total Fwd Packets:9', 'Destination Port:443'} поддержка: 1005
# {'Label:BENIGN', 'Total Fwd Packets:9', 'Destination Port:443'} поддержка: 1005
# {'Label:BENIGN', 'Total Fwd Packets:9', 'Destination Port:443', 'Protocol:6'} поддержка: 1005
# {'Total Fwd Packets:7', 'Label:DDoS'} поддержка: 1001
# {'Protocol:6', 'Total Fwd Packets:7', 'Label:DDoS'} поддержка: 1001
# {'Total Fwd Packets:7', 'Destination Port:80', 'Label:DDoS'} поддержка: 1001
# {'Protocol:6', 'Total Fwd Packets:7', 'Destination Port:80', 'Label:DDoS'} поддержка: 1001
# {'Total Fwd Packets:1', 'Destination Port:80'} поддержка: 1001
# {'Protocol:6', 'Total Fwd Packets:1', 'Destination Port:80'} поддержка: 1001
# {'Label:BENIGN', 'Total Fwd Packets:1', 'Destination Port:80'} поддержка: 957
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:1', 'Destination Port:80'} поддержка: 957
# {'Total Fwd Packets:5', 'Destination Port:443'} поддержка: 913
# {'Total Fwd Packets:5', 'Protocol:6', 'Destination Port:443'} поддержка: 913
# {'Total Fwd Packets:5', 'Destination Port:443', 'Label:BENIGN'} поддержка: 913
# {'Total Fwd Packets:5', 'Protocol:6', 'Destination Port:443', 'Label:BENIGN'} поддержка: 913
# {'Label:BENIGN', 'Protocol:6', 'Total Fwd Packets:4'} поддержка: 799
# {'Total Fwd Packets:16'} поддержка: 782
# {'Label:BENIGN', 'Total Fwd Packets:16'} поддержка: 782
# {'Protocol:6', 'Total Fwd Packets:16'} поддержка: 782
# {'Flow Duration:4'} поддержка: 780
# {'Label:BENIGN', 'Flow Duration:4'} поддержка: 775
# {'Protocol:6', 'Flow Duration:4'} поддержка: 743
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:4'} поддержка: 738
# {'Total Fwd Packets:10'} поддержка: 737
# {'Label:BENIGN', 'Total Fwd Packets:10'} поддержка: 734
# {'Protocol:6', 'Total Fwd Packets:10'} поддержка: 732
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:10'} поддержка: 729
# {'Total Fwd Packets:7', 'Destination Port:443'} поддержка: 709
# {'Protocol:6', 'Total Fwd Packets:7', 'Destination Port:443'} поддержка: 709
# {'Label:BENIGN', 'Total Fwd Packets:7', 'Destination Port:443'} поддержка: 709
# {'Label:BENIGN', 'Total Fwd Packets:7', 'Destination Port:443', 'Protocol:6'} поддержка: 709
# {'Destination Port:443', 'Total Fwd Packets:1'} поддержка: 709
# {'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:1'} поддержка: 709
# {'Label:BENIGN', 'Destination Port:443', 'Total Fwd Packets:1'} поддержка: 709
# {'Label:BENIGN', 'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:1'} поддержка: 709
# {'Destination Port:443', 'Total Fwd Packets:6'} поддержка: 600
# {'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:6'} поддержка: 600
# {'Label:BENIGN', 'Destination Port:443', 'Total Fwd Packets:6'} поддержка: 600
# {'Label:BENIGN', 'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:6'} поддержка: 600
# {'Total Fwd Packets:2', 'Flow Duration:4'} поддержка: 590
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:4'} поддержка: 589
# {'Total Fwd Packets:13'} поддержка: 587
# {'Total Fwd Packets:13', 'Label:BENIGN'} поддержка: 587
# {'Destination Port:443', 'Total Fwd Packets:10'} поддержка: 568
# {'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:10'} поддержка: 568
# {'Label:BENIGN', 'Destination Port:443', 'Total Fwd Packets:10'} поддержка: 568
# {'Label:BENIGN', 'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:10'} поддержка: 568
# {'Destination Port:443', 'Total Fwd Packets:3'} поддержка: 559
# {'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:3'} поддержка: 559
# {'Label:BENIGN', 'Destination Port:443', 'Total Fwd Packets:3'} поддержка: 559
# {'Label:BENIGN', 'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:3'} поддержка: 559
# {'Protocol:6', 'Total Fwd Packets:2', 'Flow Duration:4'} поддержка: 553
# {'Protocol:6', 'Total Fwd Packets:2', 'Flow Duration:4', 'Label:BENIGN'} поддержка: 552
# {'Destination Port:8080'} поддержка: 510
# {'Protocol:6', 'Destination Port:8080'} поддержка: 510
# {'Label:BENIGN', 'Destination Port:8080'} поддержка: 510
# {'Protocol:6', 'Destination Port:8080', 'Label:BENIGN'} поддержка: 484
# {'Total Fwd Packets:15'} поддержка: 481
# {'Total Fwd Packets:15', 'Protocol:6'} поддержка: 481
# {'Total Fwd Packets:15', 'Label:BENIGN'} поддержка: 481
# {'Destination Port:8080', 'Total Fwd Packets:3'} поддержка: 481
# {'Protocol:6', 'Destination Port:8080', 'Total Fwd Packets:3'} поддержка: 481
# {'Label:BENIGN', 'Destination Port:8080', 'Total Fwd Packets:3'} поддержка: 481
# {'Label:BENIGN', 'Protocol:6', 'Destination Port:8080', 'Total Fwd Packets:3'} поддержка: 481
# {'Total Fwd Packets:16', 'Destination Port:80'} поддержка: 461
# {'Protocol:6', 'Total Fwd Packets:16', 'Destination Port:80'} поддержка: 461
# {'Label:BENIGN', 'Total Fwd Packets:16', 'Destination Port:80'} поддержка: 461
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:16', 'Destination Port:80'} поддержка: 461
# {'Total Fwd Packets:14'} поддержка: 435
# {'Label:BENIGN', 'Total Fwd Packets:14'} поддержка: 435
# {'Protocol:6', 'Total Fwd Packets:14'} поддержка: 435
# {'Flow Duration:1'} поддержка: 428
# {'Flow Duration:1', 'Label:BENIGN'} поддержка: 427
# {'Protocol:6', 'Flow Duration:1'} поддержка: 426
# {'Protocol:6', 'Flow Duration:1', 'Label:BENIGN'} поддержка: 425
# {'Total Fwd Packets:13', 'Protocol:6'} поддержка: 394
# {'Total Fwd Packets:13', 'Protocol:6', 'Label:BENIGN'} поддержка: 394
# {'Flow Duration:1', 'Total Fwd Packets:2'} поддержка: 393
# {'Label:BENIGN', 'Flow Duration:1', 'Total Fwd Packets:2'} поддержка: 393
# {'Total Fwd Packets:15', 'Destination Port:443'} поддержка: 393
# {'Total Fwd Packets:15', 'Protocol:6', 'Destination Port:443'} поддержка: 393
# {'Total Fwd Packets:15', 'Destination Port:443', 'Label:BENIGN'} поддержка: 393
# {'Total Fwd Packets:15', 'Protocol:6', 'Destination Port:443', 'Label:BENIGN'} поддержка: 393
# {'Protocol:6', 'Flow Duration:1', 'Total Fwd Packets:2'} поддержка: 391
# {'Protocol:6', 'Flow Duration:1', 'Total Fwd Packets:2', 'Label:BENIGN'} поддержка: 391
# {'Total Fwd Packets:11'} поддержка: 390
# {'Protocol:6', 'Total Fwd Packets:11'} поддержка: 390
# {'Label:BENIGN', 'Total Fwd Packets:11'} поддержка: 389
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:11'} поддержка: 389
# {'Destination Port:443', 'Total Fwd Packets:14'} поддержка: 372
# {'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:14'} поддержка: 372
# {'Label:BENIGN', 'Destination Port:443', 'Total Fwd Packets:14'} поддержка: 372
# {'Label:BENIGN', 'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:14'} поддержка: 372
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:14'} поддержка: 372
# {'Destination Port:123'} поддержка: 362
# {'Label:BENIGN', 'Destination Port:123'} поддержка: 362
# {'Protocol:17', 'Destination Port:123'} поддержка: 362
# {'Label:BENIGN', 'Protocol:17', 'Destination Port:123'} поддержка: 362
# {'Total Fwd Packets:20'} поддержка: 352
# {'Protocol:6', 'Total Fwd Packets:20'} поддержка: 352
# {'Label:BENIGN', 'Total Fwd Packets:20'} поддержка: 352
# {'Total Fwd Packets:12'} поддержка: 348
# {'Label:BENIGN', 'Total Fwd Packets:12'} поддержка: 348
# {'Protocol:6', 'Total Fwd Packets:12'} поддержка: 348
# {'Total Fwd Packets:17'} поддержка: 348
# {'Protocol:6', 'Total Fwd Packets:17'} поддержка: 348
# {'Label:BENIGN', 'Total Fwd Packets:17'} поддержка: 348
# {'Total Fwd Packets:18'} поддержка: 347
# {'Label:BENIGN', 'Total Fwd Packets:18'} поддержка: 347
# {'Protocol:6', 'Total Fwd Packets:18'} поддержка: 347
# {'Destination Port:22'} поддержка: 342
# {'Protocol:6', 'Destination Port:22'} поддержка: 342
# {'Label:BENIGN', 'Destination Port:22'} поддержка: 342
# {'Total Fwd Packets:13', 'Destination Port:443'} поддержка: 331
# {'Total Fwd Packets:13', 'Protocol:6', 'Destination Port:443'} поддержка: 331
# {'Total Fwd Packets:13', 'Destination Port:443', 'Label:BENIGN'} поддержка: 331
# {'Total Fwd Packets:13', 'Protocol:6', 'Destination Port:443', 'Label:BENIGN'} поддержка: 331
# {'Total Fwd Packets:22'} поддержка: 326
# {'Label:BENIGN', 'Total Fwd Packets:22'} поддержка: 326
# {'Protocol:6', 'Total Fwd Packets:22'} поддержка: 326
# {'Protocol:6', 'Label:BENIGN', 'Destination Port:22'} поддержка: 318
# {'Label:BENIGN', 'Total Fwd Packets:4', 'Destination Port:80'} поддержка: 314
# {'Label:BENIGN', 'Protocol:6', 'Total Fwd Packets:4', 'Destination Port:80'} поддержка: 314
# {'Total Fwd Packets:21'} поддержка: 311
# {'Total Fwd Packets:21', 'Label:BENIGN'} поддержка: 311
# {'Total Fwd Packets:21', 'Protocol:6'} поддержка: 311
# {'Destination Port:443', 'Total Fwd Packets:11'} поддержка: 292
# {'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:11'} поддержка: 292
# {'Label:BENIGN', 'Destination Port:443', 'Total Fwd Packets:11'} поддержка: 292
# {'Label:BENIGN', 'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:11'} поддержка: 292
# {'Destination Port:443', 'Total Fwd Packets:16'} поддержка: 286
# {'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:16'} поддержка: 286
# {'Label:BENIGN', 'Destination Port:443', 'Total Fwd Packets:16'} поддержка: 286
# {'Label:BENIGN', 'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:16'} поддержка: 286
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:16'} поддержка: 286
# {'Destination Port:443', 'Total Fwd Packets:12'} поддержка: 278
# {'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:12'} поддержка: 278
# {'Label:BENIGN', 'Destination Port:443', 'Total Fwd Packets:12'} поддержка: 278
# {'Label:BENIGN', 'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:12'} поддержка: 278
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:12'} поддержка: 278
# {'Total Fwd Packets:19'} поддержка: 276
# {'Label:BENIGN', 'Total Fwd Packets:19'} поддержка: 276
# {'Protocol:6', 'Total Fwd Packets:19'} поддержка: 276
# {'Destination Port:137'} поддержка: 274
# {'Destination Port:137', 'Label:BENIGN'} поддержка: 274
# {'Destination Port:137', 'Protocol:17'} поддержка: 274
# {'Destination Port:137', 'Label:BENIGN', 'Protocol:17'} поддержка: 274
# {'Total Fwd Packets:1', 'Destination Port:123'} поддержка: 266
# {'Label:BENIGN', 'Total Fwd Packets:1', 'Destination Port:123'} поддержка: 266
# {'Protocol:17', 'Total Fwd Packets:1', 'Destination Port:123'} поддержка: 266
# {'Protocol:17', 'Label:BENIGN', 'Total Fwd Packets:1', 'Destination Port:123'} поддержка: 266
# {'Destination Port:389'} поддержка: 261
# {'Label:BENIGN', 'Destination Port:389'} поддержка: 261
# {'Total Fwd Packets:21', 'Destination Port:443'} поддержка: 248
# {'Total Fwd Packets:21', 'Protocol:6', 'Destination Port:443'} поддержка: 248
# {'Total Fwd Packets:21', 'Destination Port:443', 'Label:BENIGN'} поддержка: 248
# {'Total Fwd Packets:21', 'Protocol:6', 'Destination Port:443', 'Label:BENIGN'} поддержка: 248
# {'Total Fwd Packets:21', 'Protocol:6', 'Label:BENIGN'} поддержка: 248
# {'Destination Port:443', 'Total Fwd Packets:22'} поддержка: 244
# {'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:22'} поддержка: 244
# {'Label:BENIGN', 'Destination Port:443', 'Total Fwd Packets:22'} поддержка: 244
# {'Label:BENIGN', 'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:22'} поддержка: 244
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:22'} поддержка: 244
# {'Flow Duration:48'} поддержка: 234
# {'Label:BENIGN', 'Flow Duration:48'} поддержка: 233
# {'Destination Port:443', 'Total Fwd Packets:20'} поддержка: 233
# {'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:20'} поддержка: 233
# {'Label:BENIGN', 'Destination Port:443', 'Total Fwd Packets:20'} поддержка: 233
# {'Label:BENIGN', 'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:20'} поддержка: 233
# {'Protocol:6', 'Flow Duration:48'} поддержка: 221
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:48'} поддержка: 220
# {'Label:BENIGN', 'Total Fwd Packets:6', 'Destination Port:80'} поддержка: 212
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:6', 'Destination Port:80'} поддержка: 212
# {'Total Fwd Packets:9', 'Label:BENIGN', 'Destination Port:80'} поддержка: 207
# {'Protocol:6', 'Total Fwd Packets:9', 'Label:BENIGN', 'Destination Port:80'} поддержка: 207
# {'Destination Port:443', 'Total Fwd Packets:17'} поддержка: 203
# {'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:17'} поддержка: 203
# {'Label:BENIGN', 'Destination Port:443', 'Total Fwd Packets:17'} поддержка: 203
# {'Label:BENIGN', 'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:17'} поддержка: 203
# {'Flow Duration:49'} поддержка: 202
# {'Label:BENIGN', 'Flow Duration:49'} поддержка: 201
# {'Protocol:6', 'Flow Duration:49'} поддержка: 197
# {'Protocol:6', 'Flow Duration:49', 'Label:BENIGN'} поддержка: 196
# {'Total Fwd Packets:13', 'Protocol:17'} поддержка: 193
# {'Total Fwd Packets:13', 'Label:BENIGN', 'Protocol:17'} поддержка: 193
# {'Flow Duration:196'} поддержка: 187
# {'Flow Duration:196', 'Label:BENIGN'} поддержка: 186
# {'Flow Duration:184'} поддержка: 182
# {'Label:BENIGN', 'Flow Duration:184'} поддержка: 182
# {'Destination Port:443', 'Total Fwd Packets:19'} поддержка: 182
# {'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:19'} поддержка: 182
# {'Label:BENIGN', 'Destination Port:443', 'Total Fwd Packets:19'} поддержка: 182
# {'Label:BENIGN', 'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:19'} поддержка: 182
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:19'} поддержка: 182
# {'Flow Duration:196', 'Total Fwd Packets:2'} поддержка: 181
# {'Label:BENIGN', 'Flow Duration:196', 'Total Fwd Packets:2'} поддержка: 181
# {'Protocol:6', 'Destination Port:389'} поддержка: 179
# {'Protocol:6', 'Label:BENIGN', 'Destination Port:389'} поддержка: 179
# {'Total Fwd Packets:2', 'Flow Duration:184'} поддержка: 177
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:184'} поддержка: 177
# {'Flow Duration:182'} поддержка: 175
# {'Label:BENIGN', 'Flow Duration:182'} поддержка: 175
# {'Destination Port:443', 'Flow Duration:3'} поддержка: 175
# {'Protocol:6', 'Destination Port:443', 'Flow Duration:3'} поддержка: 175
# {'Label:BENIGN', 'Destination Port:443', 'Flow Duration:3'} поддержка: 175
# {'Label:BENIGN', 'Protocol:6', 'Destination Port:443', 'Flow Duration:3'} поддержка: 175
# {'Destination Port:88'} поддержка: 173
# {'Label:BENIGN', 'Destination Port:88'} поддержка: 173
# {'Total Fwd Packets:2', 'Flow Duration:182'} поддержка: 173
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:182'} поддержка: 173
# {'Total Fwd Packets:23'} поддержка: 172
# {'Label:BENIGN', 'Total Fwd Packets:23'} поддержка: 172
# {'Protocol:6', 'Total Fwd Packets:23'} поддержка: 172
# {'Flow Duration:2'} поддержка: 171
# {'Flow Duration:196', 'Protocol:17'} поддержка: 171
# {'Flow Duration:196', 'Label:BENIGN', 'Protocol:17'} поддержка: 171
# {'Flow Duration:196', 'Total Fwd Packets:2', 'Protocol:17'} поддержка: 171
# {'Label:BENIGN', 'Flow Duration:196', 'Total Fwd Packets:2', 'Protocol:17'} поддержка: 171
# {'Flow Duration:196', 'Destination Port:53'} поддержка: 171
# {'Flow Duration:196', 'Label:BENIGN', 'Destination Port:53'} поддержка: 171
# {'Flow Duration:196', 'Total Fwd Packets:2', 'Destination Port:53'} поддержка: 171
# {'Label:BENIGN', 'Flow Duration:196', 'Total Fwd Packets:2', 'Destination Port:53'} поддержка: 171
# {'Flow Duration:196', 'Protocol:17', 'Destination Port:53'} поддержка: 171
# {'Flow Duration:196', 'Label:BENIGN', 'Protocol:17', 'Destination Port:53'} поддержка: 171
# {'Flow Duration:196', 'Total Fwd Packets:2', 'Protocol:17', 'Destination Port:53'} поддержка: 171
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Destination Port:53', 'Flow Duration:196', 'Protocol:17'} поддержка: 171
# {'Total Fwd Packets:25'} поддержка: 170
# {'Total Fwd Packets:25', 'Label:BENIGN'} поддержка: 170
# {'Total Fwd Packets:25', 'Protocol:6'} поддержка: 170
# {'Flow Duration:204'} поддержка: 170
# {'Label:BENIGN', 'Flow Duration:204'} поддержка: 170
# {'Label:BENIGN', 'Flow Duration:2'} поддержка: 170
# {'Label:BENIGN', 'Total Fwd Packets:5', 'Destination Port:80'} поддержка: 170
# {'Label:BENIGN', 'Protocol:6', 'Total Fwd Packets:5', 'Destination Port:80'} поддержка: 170
# {'Total Fwd Packets:2', 'Destination Port:443', 'Flow Duration:3'} поддержка: 169
# {'Protocol:6', 'Total Fwd Packets:2', 'Destination Port:443', 'Flow Duration:3'} поддержка: 169
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Destination Port:443', 'Flow Duration:3'} поддержка: 169
# {'Label:BENIGN', 'Destination Port:443', 'Total Fwd Packets:2', 'Flow Duration:3', 'Protocol:6'} поддержка: 169
# {'Destination Port:21'} поддержка: 167
# {'Destination Port:21', 'Protocol:6'} поддержка: 167
# {'Destination Port:21', 'Label:BENIGN'} поддержка: 167
# {'Flow Duration:177'} поддержка: 167
# {'Flow Duration:193'} поддержка: 167
# {'Label:BENIGN', 'Flow Duration:193'} поддержка: 167
# {'Total Fwd Packets:2', 'Flow Duration:204'} поддержка: 167
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:204'} поддержка: 167
# {'Flow Duration:198'} поддержка: 166
# {'Label:BENIGN', 'Flow Duration:198'} поддержка: 166
# {'Flow Duration:191'} поддержка: 166
# {'Label:BENIGN', 'Flow Duration:191'} поддержка: 166
# {'Label:BENIGN', 'Flow Duration:177'} поддержка: 166
# {'Protocol:6', 'Flow Duration:2'} поддержка: 166
# {'Flow Duration:186'} поддержка: 165
# {'Flow Duration:186', 'Label:BENIGN'} поддержка: 165
# {'Protocol:6', 'Flow Duration:2', 'Label:BENIGN'} поддержка: 165
# {'Protocol:17', 'Flow Duration:184'} поддержка: 165
# {'Label:BENIGN', 'Protocol:17', 'Flow Duration:184'} поддержка: 165
# {'Total Fwd Packets:2', 'Protocol:17', 'Flow Duration:184'} поддержка: 165
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Protocol:17', 'Flow Duration:184'} поддержка: 165
# {'Flow Duration:184', 'Destination Port:53'} поддержка: 164
# {'Label:BENIGN', 'Flow Duration:184', 'Destination Port:53'} поддержка: 164
# {'Total Fwd Packets:2', 'Flow Duration:184', 'Destination Port:53'} поддержка: 164
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:184', 'Destination Port:53'} поддержка: 164
# {'Protocol:17', 'Flow Duration:184', 'Destination Port:53'} поддержка: 164
# {'Label:BENIGN', 'Protocol:17', 'Flow Duration:184', 'Destination Port:53'} поддержка: 164
# {'Total Fwd Packets:2', 'Protocol:17', 'Flow Duration:184', 'Destination Port:53'} поддержка: 164
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Destination Port:53', 'Protocol:17', 'Flow Duration:184'} поддержка: 164
# {'Total Fwd Packets:2', 'Flow Duration:191'} поддержка: 162
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:191'} поддержка: 162
# {'Total Fwd Packets:2', 'Flow Duration:177'} поддержка: 162
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:177'} поддержка: 162
# {'Total Fwd Packets:2', 'Flow Duration:193'} поддержка: 161
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:193'} поддержка: 161
# {'Flow Duration:182', 'Protocol:17'} поддержка: 161
# {'Label:BENIGN', 'Flow Duration:182', 'Protocol:17'} поддержка: 161
# {'Total Fwd Packets:2', 'Flow Duration:182', 'Protocol:17'} поддержка: 161
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:182', 'Protocol:17'} поддержка: 161
# {'Total Fwd Packets:2', 'Flow Duration:48'} поддержка: 161
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:48'} поддержка: 161
# {'Flow Duration:182', 'Destination Port:53'} поддержка: 160
# {'Label:BENIGN', 'Flow Duration:182', 'Destination Port:53'} поддержка: 160
# {'Total Fwd Packets:2', 'Flow Duration:182', 'Destination Port:53'} поддержка: 160
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:182', 'Destination Port:53'} поддержка: 160
# {'Protocol:17', 'Flow Duration:182', 'Destination Port:53'} поддержка: 160
# {'Protocol:17', 'Label:BENIGN', 'Flow Duration:182', 'Destination Port:53'} поддержка: 160
# {'Protocol:17', 'Total Fwd Packets:2', 'Flow Duration:182', 'Destination Port:53'} поддержка: 160
# {'Label:BENIGN', 'Flow Duration:182', 'Total Fwd Packets:2', 'Destination Port:53', 'Protocol:17'} поддержка: 160
# {'Total Fwd Packets:2', 'Flow Duration:198'} поддержка: 159
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:198'} поддержка: 159
# {'Flow Duration:195'} поддержка: 157
# {'Label:BENIGN', 'Flow Duration:195'} поддержка: 157
# {'Flow Duration:186', 'Total Fwd Packets:2'} поддержка: 157
# {'Flow Duration:186', 'Total Fwd Packets:2', 'Label:BENIGN'} поддержка: 157
# {'Total Fwd Packets:24'} поддержка: 156
# {'Total Fwd Packets:24', 'Label:BENIGN'} поддержка: 156
# {'Protocol:6', 'Total Fwd Packets:24'} поддержка: 156
# {'Flow Duration:194'} поддержка: 156
# {'Label:BENIGN', 'Flow Duration:194'} поддержка: 156
# {'Flow Duration:193', 'Protocol:17'} поддержка: 156
# {'Label:BENIGN', 'Flow Duration:193', 'Protocol:17'} поддержка: 156
# {'Total Fwd Packets:2', 'Flow Duration:193', 'Protocol:17'} поддержка: 156
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:193', 'Protocol:17'} поддержка: 156
# {'Destination Port:443', 'Total Fwd Packets:18'} поддержка: 156
# {'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:18'} поддержка: 156
# {'Label:BENIGN', 'Destination Port:443', 'Total Fwd Packets:18'} поддержка: 156
# {'Label:BENIGN', 'Destination Port:443', 'Total Fwd Packets:18', 'Protocol:6'} поддержка: 156
# {'Label:BENIGN', 'Protocol:6', 'Total Fwd Packets:18'} поддержка: 156
# {'Flow Duration:192'} поддержка: 154
# {'Flow Duration:192', 'Label:BENIGN'} поддержка: 154
# {'Total Fwd Packets:2', 'Flow Duration:195'} поддержка: 154
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:195'} поддержка: 154
# {'Flow Duration:193', 'Destination Port:53'} поддержка: 154
# {'Label:BENIGN', 'Flow Duration:193', 'Destination Port:53'} поддержка: 154
# {'Total Fwd Packets:2', 'Flow Duration:193', 'Destination Port:53'} поддержка: 154
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:193', 'Destination Port:53'} поддержка: 154
# {'Flow Duration:193', 'Protocol:17', 'Destination Port:53'} поддержка: 154
# {'Label:BENIGN', 'Flow Duration:193', 'Protocol:17', 'Destination Port:53'} поддержка: 154
# {'Total Fwd Packets:2', 'Flow Duration:193', 'Protocol:17', 'Destination Port:53'} поддержка: 154
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Destination Port:53', 'Flow Duration:193', 'Protocol:17'} поддержка: 154
# {'Flow Duration:177', 'Protocol:17'} поддержка: 153
# {'Label:BENIGN', 'Flow Duration:177', 'Protocol:17'} поддержка: 153
# {'Total Fwd Packets:2', 'Flow Duration:177', 'Protocol:17'} поддержка: 153
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:177', 'Protocol:17'} поддержка: 153
# {'Protocol:17', 'Flow Duration:204'} поддержка: 153
# {'Label:BENIGN', 'Protocol:17', 'Flow Duration:204'} поддержка: 153
# {'Total Fwd Packets:2', 'Protocol:17', 'Flow Duration:204'} поддержка: 153
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Protocol:17', 'Flow Duration:204'} поддержка: 153
# {'Flow Duration:204', 'Destination Port:53'} поддержка: 152
# {'Label:BENIGN', 'Flow Duration:204', 'Destination Port:53'} поддержка: 152
# {'Total Fwd Packets:2', 'Flow Duration:204', 'Destination Port:53'} поддержка: 152
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:204', 'Destination Port:53'} поддержка: 152
# {'Protocol:17', 'Flow Duration:204', 'Destination Port:53'} поддержка: 152
# {'Label:BENIGN', 'Protocol:17', 'Flow Duration:204', 'Destination Port:53'} поддержка: 152
# {'Total Fwd Packets:2', 'Protocol:17', 'Flow Duration:204', 'Destination Port:53'} поддержка: 152
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:204', 'Destination Port:53', 'Protocol:17'} поддержка: 152
# {'Flow Duration:187'} поддержка: 151
# {'Flow Duration:187', 'Label:BENIGN'} поддержка: 151
# {'Total Fwd Packets:2', 'Flow Duration:194'} поддержка: 151
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:194'} поддержка: 151
# {'Total Fwd Packets:1', 'Destination Port:22'} поддержка: 151
# {'Protocol:6', 'Total Fwd Packets:1', 'Destination Port:22'} поддержка: 151
# {'Label:BENIGN', 'Total Fwd Packets:1', 'Destination Port:22'} поддержка: 151
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:1', 'Destination Port:22'} поддержка: 151
# {'Total Fwd Packets:18', 'Destination Port:80'} поддержка: 151
# {'Protocol:6', 'Total Fwd Packets:18', 'Destination Port:80'} поддержка: 151
# {'Label:BENIGN', 'Total Fwd Packets:18', 'Destination Port:80'} поддержка: 151
# {'Label:BENIGN', 'Protocol:6', 'Total Fwd Packets:18', 'Destination Port:80'} поддержка: 151
# {'Flow Duration:188'} поддержка: 150
# {'Label:BENIGN', 'Flow Duration:188'} поддержка: 150
# {'Flow Duration:189'} поддержка: 149
# {'Label:BENIGN', 'Flow Duration:189'} поддержка: 149
# {'Flow Duration:173'} поддержка: 149
# {'Label:BENIGN', 'Flow Duration:173'} поддержка: 149
# {'Flow Duration:174'} поддержка: 149
# {'Flow Duration:174', 'Label:BENIGN'} поддержка: 149
# {'Flow Duration:183'} поддержка: 149
# {'Flow Duration:183', 'Label:BENIGN'} поддержка: 149
# {'Flow Duration:202'} поддержка: 149
# {'Flow Duration:202', 'Label:BENIGN'} поддержка: 149
# {'Flow Duration:198', 'Protocol:17'} поддержка: 149
# {'Label:BENIGN', 'Flow Duration:198', 'Protocol:17'} поддержка: 149
# {'Total Fwd Packets:2', 'Flow Duration:198', 'Protocol:17'} поддержка: 149
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:198', 'Protocol:17'} поддержка: 149
# {'Total Fwd Packets:10', 'Destination Port:80'} поддержка: 149
# {'Protocol:6', 'Total Fwd Packets:10', 'Destination Port:80'} поддержка: 149
# {'Total Fwd Packets:2', 'Flow Duration:188'} поддержка: 148
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:188'} поддержка: 148
# {'Flow Duration:192', 'Total Fwd Packets:2'} поддержка: 148
# {'Label:BENIGN', 'Flow Duration:192', 'Total Fwd Packets:2'} поддержка: 148
# {'Protocol:17', 'Flow Duration:195'} поддержка: 148
# {'Label:BENIGN', 'Protocol:17', 'Flow Duration:195'} поддержка: 148
# {'Total Fwd Packets:2', 'Protocol:17', 'Flow Duration:195'} поддержка: 148
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Protocol:17', 'Flow Duration:195'} поддержка: 148
# {'Destination Port:53', 'Flow Duration:195'} поддержка: 148
# {'Destination Port:53', 'Label:BENIGN', 'Flow Duration:195'} поддержка: 148
# {'Destination Port:53', 'Total Fwd Packets:2', 'Flow Duration:195'} поддержка: 148
# {'Destination Port:53', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:195'} поддержка: 148
# {'Destination Port:53', 'Protocol:17', 'Flow Duration:195'} поддержка: 148
# {'Destination Port:53', 'Label:BENIGN', 'Protocol:17', 'Flow Duration:195'} поддержка: 148
# {'Destination Port:53', 'Total Fwd Packets:2', 'Protocol:17', 'Flow Duration:195'} поддержка: 148
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Destination Port:53', 'Protocol:17', 'Flow Duration:195'} поддержка: 148
# {'Flow Duration:177', 'Destination Port:53'} поддержка: 148
# {'Label:BENIGN', 'Flow Duration:177', 'Destination Port:53'} поддержка: 148
# {'Total Fwd Packets:2', 'Flow Duration:177', 'Destination Port:53'} поддержка: 148
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:177', 'Destination Port:53'} поддержка: 148
# {'Flow Duration:177', 'Protocol:17', 'Destination Port:53'} поддержка: 148
# {'Label:BENIGN', 'Flow Duration:177', 'Protocol:17', 'Destination Port:53'} поддержка: 148
# {'Total Fwd Packets:2', 'Flow Duration:177', 'Protocol:17', 'Destination Port:53'} поддержка: 148
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:177', 'Destination Port:53', 'Protocol:17'} поддержка: 148
# {'Protocol:6', 'Total Fwd Packets:2', 'Flow Duration:48'} поддержка: 148
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:48'} поддержка: 148
# {'Label:BENIGN', 'Total Fwd Packets:8', 'Destination Port:80'} поддержка: 148
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:8', 'Destination Port:80'} поддержка: 148
# {'Total Fwd Packets:26'} поддержка: 147
# {'Label:BENIGN', 'Total Fwd Packets:26'} поддержка: 147
# {'Destination Port:465'} поддержка: 147
# {'Protocol:6', 'Destination Port:465'} поддержка: 147
# {'Label:BENIGN', 'Destination Port:465'} поддержка: 147
# {'Flow Duration:200'} поддержка: 147
# {'Label:BENIGN', 'Flow Duration:200'} поддержка: 147
# {'Flow Duration:201'} поддержка: 147
# {'Label:BENIGN', 'Flow Duration:201'} поддержка: 147
# {'Total Fwd Packets:2', 'Flow Duration:173'} поддержка: 147
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:173'} поддержка: 147
# {'Flow Duration:174', 'Total Fwd Packets:2'} поддержка: 147
# {'Label:BENIGN', 'Flow Duration:174', 'Total Fwd Packets:2'} поддержка: 147
# {'Flow Duration:198', 'Destination Port:53'} поддержка: 147
# {'Label:BENIGN', 'Flow Duration:198', 'Destination Port:53'} поддержка: 147
# {'Total Fwd Packets:2', 'Flow Duration:198', 'Destination Port:53'} поддержка: 147
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:198', 'Destination Port:53'} поддержка: 147
# {'Protocol:17', 'Flow Duration:198', 'Destination Port:53'} поддержка: 147
# {'Protocol:17', 'Label:BENIGN', 'Flow Duration:198', 'Destination Port:53'} поддержка: 147
# {'Protocol:17', 'Total Fwd Packets:2', 'Flow Duration:198', 'Destination Port:53'} поддержка: 147
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Destination Port:53', 'Protocol:17', 'Flow Duration:198'} поддержка: 147
# {'Protocol:17', 'Flow Duration:191'} поддержка: 147
# {'Label:BENIGN', 'Protocol:17', 'Flow Duration:191'} поддержка: 147
# {'Total Fwd Packets:2', 'Protocol:17', 'Flow Duration:191'} поддержка: 147
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Protocol:17', 'Flow Duration:191'} поддержка: 147
# {'Flow Duration:181'} поддержка: 146
# {'Label:BENIGN', 'Flow Duration:181'} поддержка: 146
# {'Flow Duration:202', 'Total Fwd Packets:2'} поддержка: 146
# {'Flow Duration:202', 'Total Fwd Packets:2', 'Label:BENIGN'} поддержка: 146
# {'Flow Duration:186', 'Protocol:17'} поддержка: 146
# {'Flow Duration:186', 'Label:BENIGN', 'Protocol:17'} поддержка: 146
# {'Flow Duration:186', 'Total Fwd Packets:2', 'Protocol:17'} поддержка: 146
# {'Flow Duration:186', 'Total Fwd Packets:2', 'Protocol:17', 'Label:BENIGN'} поддержка: 146
# {'Flow Duration:186', 'Destination Port:53'} поддержка: 146
# {'Flow Duration:186', 'Label:BENIGN', 'Destination Port:53'} поддержка: 146
# {'Flow Duration:186', 'Total Fwd Packets:2', 'Destination Port:53'} поддержка: 146
# {'Flow Duration:186', 'Total Fwd Packets:2', 'Label:BENIGN', 'Destination Port:53'} поддержка: 146
# {'Flow Duration:186', 'Protocol:17', 'Destination Port:53'} поддержка: 146
# {'Flow Duration:186', 'Label:BENIGN', 'Protocol:17', 'Destination Port:53'} поддержка: 146
# {'Flow Duration:186', 'Total Fwd Packets:2', 'Protocol:17', 'Destination Port:53'} поддержка: 146
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Destination Port:53', 'Flow Duration:186', 'Protocol:17'} поддержка: 146
# {'Destination Port:53', 'Flow Duration:191'} поддержка: 146
# {'Destination Port:53', 'Label:BENIGN', 'Flow Duration:191'} поддержка: 146
# {'Destination Port:53', 'Total Fwd Packets:2', 'Flow Duration:191'} поддержка: 146
# {'Destination Port:53', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:191'} поддержка: 146
# {'Destination Port:53', 'Protocol:17', 'Flow Duration:191'} поддержка: 146
# {'Destination Port:53', 'Label:BENIGN', 'Protocol:17', 'Flow Duration:191'} поддержка: 146
# {'Destination Port:53', 'Total Fwd Packets:2', 'Protocol:17', 'Flow Duration:191'} поддержка: 146
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Destination Port:53', 'Flow Duration:191', 'Protocol:17'} поддержка: 146
# {'Label:BENIGN', 'Total Fwd Packets:10', 'Destination Port:80'} поддержка: 146
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:10', 'Destination Port:80'} поддержка: 146
# {'Flow Duration:199'} поддержка: 145
# {'Flow Duration:199', 'Label:BENIGN'} поддержка: 145
# {'Flow Duration:171'} поддержка: 145
# {'Label:BENIGN', 'Flow Duration:171'} поддержка: 145
# {'Flow Duration:185'} поддержка: 145
# {'Label:BENIGN', 'Flow Duration:185'} поддержка: 145
# {'Flow Duration:205'} поддержка: 145
# {'Label:BENIGN', 'Flow Duration:205'} поддержка: 145
# {'Flow Duration:209'} поддержка: 145
# {'Label:BENIGN', 'Flow Duration:209'} поддержка: 145
# {'Flow Duration:219'} поддержка: 145
# {'Label:BENIGN', 'Flow Duration:219'} поддержка: 145
# {'Flow Duration:187', 'Total Fwd Packets:2'} поддержка: 145
# {'Label:BENIGN', 'Flow Duration:187', 'Total Fwd Packets:2'} поддержка: 145
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:17'} поддержка: 145
# {'Total Fwd Packets:2', 'Flow Duration:205'} поддержка: 144
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:205'} поддержка: 144
# {'Total Fwd Packets:2', 'Flow Duration:200'} поддержка: 144
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:200'} поддержка: 144
# {'Total Fwd Packets:2', 'Flow Duration:189'} поддержка: 144
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:189'} поддержка: 144
# {'Flow Duration:183', 'Total Fwd Packets:2'} поддержка: 144
# {'Flow Duration:183', 'Total Fwd Packets:2', 'Label:BENIGN'} поддержка: 144
# {'Flow Duration:194', 'Protocol:17'} поддержка: 144
# {'Label:BENIGN', 'Flow Duration:194', 'Protocol:17'} поддержка: 144
# {'Total Fwd Packets:2', 'Flow Duration:194', 'Protocol:17'} поддержка: 144
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:194', 'Protocol:17'} поддержка: 144
# {'Flow Duration:194', 'Destination Port:53'} поддержка: 144
# {'Label:BENIGN', 'Flow Duration:194', 'Destination Port:53'} поддержка: 144
# {'Total Fwd Packets:2', 'Flow Duration:194', 'Destination Port:53'} поддержка: 144
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:194', 'Destination Port:53'} поддержка: 144
# {'Protocol:17', 'Flow Duration:194', 'Destination Port:53'} поддержка: 144
# {'Protocol:17', 'Label:BENIGN', 'Flow Duration:194', 'Destination Port:53'} поддержка: 144
# {'Protocol:17', 'Total Fwd Packets:2', 'Flow Duration:194', 'Destination Port:53'} поддержка: 144
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:194', 'Destination Port:53', 'Protocol:17'} поддержка: 144
# {'Destination Port:443', 'Total Fwd Packets:23'} поддержка: 143
# {'Protocol:6', 'Destination Port:443', 'Total Fwd Packets:23'} поддержка: 143
# {'Label:BENIGN', 'Destination Port:443', 'Total Fwd Packets:23'} поддержка: 143
# {'Label:BENIGN', 'Destination Port:443', 'Total Fwd Packets:23', 'Protocol:6'} поддержка: 143
# {'Label:BENIGN', 'Protocol:6', 'Total Fwd Packets:23'} поддержка: 143
# {'Flow Duration:166'} поддержка: 142
# {'Flow Duration:166', 'Label:BENIGN'} поддержка: 142
# {'Flow Duration:207'} поддержка: 142
# {'Label:BENIGN', 'Flow Duration:207'} поддержка: 142
# {'Flow Duration:206'} поддержка: 142
# {'Label:BENIGN', 'Flow Duration:206'} поддержка: 142
# {'Flow Duration:190'} поддержка: 142
# {'Flow Duration:190', 'Label:BENIGN'} поддержка: 142
# {'Flow Duration:168'} поддержка: 142
# {'Label:BENIGN', 'Flow Duration:168'} поддержка: 142
# {'Total Fwd Packets:2', 'Flow Duration:201'} поддержка: 142
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:201'} поддержка: 142
# {'Flow Duration:208'} поддержка: 141
# {'Label:BENIGN', 'Flow Duration:208'} поддержка: 141
# {'Flow Duration:217'} поддержка: 141
# {'Flow Duration:217', 'Label:BENIGN'} поддержка: 141
# {'Flow Duration:169'} поддержка: 141
# {'Label:BENIGN', 'Flow Duration:169'} поддержка: 141
# {'Flow Duration:197'} поддержка: 141
# {'Label:BENIGN', 'Flow Duration:197'} поддержка: 141
# {'Flow Duration:215'} поддержка: 141
# {'Flow Duration:215', 'Label:BENIGN'} поддержка: 141
# {'Total Fwd Packets:2', 'Flow Duration:209'} поддержка: 141
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:209'} поддержка: 141
# {'Flow Duration:199', 'Total Fwd Packets:2'} поддержка: 140
# {'Label:BENIGN', 'Flow Duration:199', 'Total Fwd Packets:2'} поддержка: 140
# {'Flow Duration:200', 'Protocol:17'} поддержка: 140
# {'Label:BENIGN', 'Flow Duration:200', 'Protocol:17'} поддержка: 140
# {'Total Fwd Packets:2', 'Flow Duration:200', 'Protocol:17'} поддержка: 140
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:200', 'Protocol:17'} поддержка: 140
# {'Flow Duration:174', 'Protocol:17'} поддержка: 140
# {'Flow Duration:174', 'Label:BENIGN', 'Protocol:17'} поддержка: 140
# {'Flow Duration:174', 'Total Fwd Packets:2', 'Protocol:17'} поддержка: 140
# {'Label:BENIGN', 'Flow Duration:174', 'Total Fwd Packets:2', 'Protocol:17'} поддержка: 140
# {'Flow Duration:174', 'Destination Port:53'} поддержка: 140
# {'Flow Duration:174', 'Label:BENIGN', 'Destination Port:53'} поддержка: 140
# {'Flow Duration:174', 'Total Fwd Packets:2', 'Destination Port:53'} поддержка: 140
# {'Label:BENIGN', 'Flow Duration:174', 'Total Fwd Packets:2', 'Destination Port:53'} поддержка: 140
# {'Flow Duration:174', 'Protocol:17', 'Destination Port:53'} поддержка: 140
# {'Flow Duration:174', 'Label:BENIGN', 'Protocol:17', 'Destination Port:53'} поддержка: 140
# {'Flow Duration:174', 'Total Fwd Packets:2', 'Protocol:17', 'Destination Port:53'} поддержка: 140
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Destination Port:53', 'Flow Duration:174', 'Protocol:17'} поддержка: 140
# {'Flow Duration:187', 'Protocol:17'} поддержка: 140
# {'Flow Duration:187', 'Label:BENIGN', 'Protocol:17'} поддержка: 140
# {'Flow Duration:187', 'Total Fwd Packets:2', 'Protocol:17'} поддержка: 140
# {'Label:BENIGN', 'Flow Duration:187', 'Total Fwd Packets:2', 'Protocol:17'} поддержка: 140
# {'Flow Duration:4', 'Total Fwd Packets:3'} поддержка: 140
# {'Protocol:6', 'Flow Duration:4', 'Total Fwd Packets:3'} поддержка: 140
# {'Label:BENIGN', 'Flow Duration:4', 'Total Fwd Packets:3'} поддержка: 140
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:4', 'Total Fwd Packets:3'} поддержка: 140
# {'Total Fwd Packets:7', 'Label:BENIGN', 'Destination Port:80'} поддержка: 140
# {'Protocol:6', 'Total Fwd Packets:7', 'Label:BENIGN', 'Destination Port:80'} поддержка: 140
# {'Total Fwd Packets:2', 'Flow Duration:208'} поддержка: 139
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:208'} поддержка: 139
# {'Total Fwd Packets:2', 'Flow Duration:168'} поддержка: 139
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:168'} поддержка: 139
# {'Total Fwd Packets:2', 'Flow Duration:171'} поддержка: 139
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:171'} поддержка: 139
# {'Total Fwd Packets:2', 'Flow Duration:181'} поддержка: 139
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:181'} поддержка: 139
# {'Flow Duration:200', 'Destination Port:53'} поддержка: 139
# {'Label:BENIGN', 'Flow Duration:200', 'Destination Port:53'} поддержка: 139
# {'Total Fwd Packets:2', 'Flow Duration:200', 'Destination Port:53'} поддержка: 139
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:200', 'Destination Port:53'} поддержка: 139
# {'Flow Duration:200', 'Protocol:17', 'Destination Port:53'} поддержка: 139
# {'Label:BENIGN', 'Flow Duration:200', 'Protocol:17', 'Destination Port:53'} поддержка: 139
# {'Total Fwd Packets:2', 'Flow Duration:200', 'Protocol:17', 'Destination Port:53'} поддержка: 139
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Destination Port:53', 'Flow Duration:200', 'Protocol:17'} поддержка: 139
# {'Protocol:17', 'Flow Duration:189'} поддержка: 139
# {'Label:BENIGN', 'Protocol:17', 'Flow Duration:189'} поддержка: 139
# {'Total Fwd Packets:2', 'Protocol:17', 'Flow Duration:189'} поддержка: 139
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Protocol:17', 'Flow Duration:189'} поддержка: 139
# {'Flow Duration:187', 'Destination Port:53'} поддержка: 139
# {'Flow Duration:187', 'Label:BENIGN', 'Destination Port:53'} поддержка: 139
# {'Flow Duration:187', 'Total Fwd Packets:2', 'Destination Port:53'} поддержка: 139
# {'Label:BENIGN', 'Flow Duration:187', 'Total Fwd Packets:2', 'Destination Port:53'} поддержка: 139
# {'Flow Duration:187', 'Protocol:17', 'Destination Port:53'} поддержка: 139
# {'Flow Duration:187', 'Label:BENIGN', 'Protocol:17', 'Destination Port:53'} поддержка: 139
# {'Flow Duration:187', 'Total Fwd Packets:2', 'Protocol:17', 'Destination Port:53'} поддержка: 139
# {'Flow Duration:187', 'Label:BENIGN', 'Total Fwd Packets:2', 'Destination Port:53', 'Protocol:17'} поддержка: 139
# ...
# {'Label:BENIGN', 'Flow Duration:488'} поддержка: 11
# {'Flow Duration:410', 'Label:BENIGN'} поддержка: 11
# {'Label:BENIGN', 'Flow Duration:380'} поддержка: 11
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:70'} поддержка: 11
# {'Flow Duration:328', 'Total Fwd Packets:2', 'Label:BENIGN'} поддержка: 11
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:71'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:55', 'Label:BENIGN'} поддержка: 11
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:66'} поддержка: 11
# {'Protocol:6', 'Label:BENIGN', 'Destination Port:49671'} поддержка: 11
# {'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:322'} поддержка: 11
# {'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:321'} поддержка: 11
# {'Protocol:6', 'Flow Duration:313', 'Label:BENIGN'} поддержка: 11
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:275'} поддержка: 11
# {'Flow Duration:75', 'Label:BENIGN', 'Total Fwd Packets:2'} поддержка: 11
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:225'} поддержка: 11
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:223'} поддержка: 11
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:160'} поддержка: 11
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:248'} поддержка: 11
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:157'} поддержка: 11
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:163'} поддержка: 11
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:206'} поддержка: 11
# {'Protocol:6', 'Flow Duration:187', 'Label:BENIGN'} поддержка: 11
# {'Protocol:6', 'Flow Duration:193', 'Label:BENIGN'} поддержка: 11
# {'Flow Duration:385', 'Label:BENIGN', 'Protocol:17', 'Destination Port:53'} поддержка: 11
# {'Destination Port:5353', 'Label:BENIGN', 'Protocol:17', 'Total Fwd Packets:13'} поддержка: 11
# {'Flow Duration:118', 'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:1'} поддержка: 11
# {'Protocol:6', 'Label:BENIGN', 'Destination Port:135', 'Total Fwd Packets:1'} поддержка: 11
# {'Protocol:6', 'Flow Duration:103', 'Label:BENIGN', 'Total Fwd Packets:2'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:126'} поддержка: 11
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:1', 'Flow Duration:113'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:117'} поддержка: 11
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:1', 'Flow Duration:125'} поддержка: 11
# {'Protocol:6', 'Destination Port:443', 'Label:BENIGN', 'Flow Duration:125'} поддержка: 11
# {'Total Fwd Packets:2', 'Label:BENIGN', 'Protocol:17', 'Flow Duration:129'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:106'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:90'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:136'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:96'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:102'} поддержка: 11
# {'Protocol:6', 'Destination Port:443', 'Label:BENIGN', 'Flow Duration:138'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:138'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:69'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:79'} поддержка: 11
# {'Total Fwd Packets:32', 'Protocol:6', 'Label:BENIGN', 'Destination Port:80'} поддержка: 11
# {'Protocol:6', 'Flow Duration:76', 'Label:BENIGN', 'Total Fwd Packets:2'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:258'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:83'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:17'} поддержка: 11
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:44', 'Destination Port:80'} поддержка: 11
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:3', 'Flow Duration:67'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:234'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:66'} поддержка: 11
# {'Protocol:6', 'Flow Duration:150', 'Label:BENIGN', 'Total Fwd Packets:2'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:56'} поддержка: 11
# {'Flow Duration:152', 'Destination Port:443', 'Label:BENIGN', 'Protocol:6'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:151'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:238'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:159'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:155'} поддержка: 11
# {'Flow Duration:210', 'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:2'} поддержка: 11
# {'Protocol:6', 'Flow Duration:215', 'Label:BENIGN', 'Total Fwd Packets:2'} поддержка: 11
# {'Protocol:6', 'Flow Duration:166', 'Label:BENIGN', 'Total Fwd Packets:1'} поддержка: 11
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:207'} поддержка: 11
# {'Flow Duration:202', 'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:2'} поддержка: 11
# {'Flow Duration:186', 'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:2'} поддержка: 11
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:3', 'Flow Duration:48'} поддержка: 11
# {'Flow Duration:309', 'Label:BENIGN', 'Total Fwd Packets:2', 'Destination Port:53', 'Protocol:17'} поддержка: 11
# {'Label:BENIGN', 'Flow Duration:335', 'Total Fwd Packets:2', 'Destination Port:53', 'Protocol:17'} поддержка: 11
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:334', 'Destination Port:53', 'Protocol:17'} поддержка: 11
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:294', 'Destination Port:53', 'Protocol:17'} поддержка: 11
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:67', 'Protocol:6', 'Destination Port:80'} поддержка: 11
# {'Destination Port:443', 'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:156', 'Protocol:6'} поддержка: 11
# {'Destination Port:21', 'Flow Duration:50', 'Label:BENIGN', 'Protocol:6', 'Total Fwd Packets:1'} поддержка: 11
# {'Destination Port:443', 'Label:BENIGN', 'Total Fwd Packets:2', 'Protocol:6', 'Flow Duration:161'} поддержка: 11
# {'Destination Port:137', 'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:48', 'Protocol:17'} поддержка: 11
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:3', 'Protocol:6', 'Destination Port:80'} поддержка: 11
# {'Label:BENIGN', 'Flow Duration:399'} поддержка: 10
# {'Label:BENIGN', 'Flow Duration:343'} поддержка: 10
# {'Label:BENIGN', 'Flow Duration:297'} поддержка: 10
# {'Label:BENIGN', 'Flow Duration:311'} поддержка: 10
# {'Label:BENIGN', 'Flow Duration:365'} поддержка: 10
# {'Label:BENIGN', 'Flow Duration:450'} поддержка: 10
# {'Label:BENIGN', 'Flow Duration:23948'} поддержка: 10
# {'Flow Duration:400', 'Label:BENIGN'} поддержка: 10
# {'Label:BENIGN', 'Flow Duration:424'} поддержка: 10
# {'Flow Duration:447', 'Label:BENIGN'} поддержка: 10
# {'Label:BENIGN', 'Flow Duration:338'} поддержка: 10
# {'Label:BENIGN', 'Total Fwd Packets:77'} поддержка: 10
# {'Label:BENIGN', 'Flow Duration:356'} поддержка: 10
# {'Label:BENIGN', 'Total Fwd Packets:104'} поддержка: 10
# {'Label:BENIGN', 'Flow Duration:425'} поддержка: 10
# {'Label:BENIGN', 'Flow Duration:473'} поддержка: 10
# {'Label:BENIGN', 'Flow Duration:421'} поддержка: 10
# {'Protocol:6', 'Flow Duration:176'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:69'} поддержка: 10
# {'Flow Duration:333', 'Total Fwd Packets:2', 'Label:BENIGN'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:74'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:60'} поддержка: 10
# {'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:345'} поддержка: 10
# {'Flow Duration:314', 'Protocol:6', 'Label:BENIGN'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:315'} поддержка: 10
# {'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:110'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:137'} поддержка: 10
# {'Flow Duration:41', 'Label:BENIGN', 'Total Fwd Packets:2'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:266'} поддержка: 10
# {'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:78'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:146'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:142'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:148'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:227'} поддержка: 10
# {'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:52'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:254'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:218'} поддержка: 10
# {'Protocol:6', 'Flow Duration:162', 'Label:BENIGN'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:168'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:171'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:201'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Flow Duration:189'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:1', 'Flow Duration:128'} поддержка: 10
# {'Protocol:6', 'Flow Duration:90', 'Destination Port:80'} поддержка: 10
# {'Protocol:6', 'Flow Duration:41', 'Total Fwd Packets:2'} поддержка: 10
# {'Protocol:6', 'Flow Duration:58', 'Destination Port:80'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:2', 'Flow Duration:57'} поддержка: 10
# {'Protocol:6', 'Flow Duration:66', 'Destination Port:80'} поддержка: 10
# {'Protocol:6', 'Flow Duration:53', 'Destination Port:80'} поддержка: 10
# {'Protocol:6', 'Destination Port:443', 'Label:BENIGN', 'Total Fwd Packets:65'} поддержка: 10
# {'Protocol:17', 'Label:BENIGN', 'Flow Duration:303', 'Destination Port:53'} поддержка: 10
# {'Protocol:6', 'Destination Port:443', 'Label:BENIGN', 'Total Fwd Packets:64'} поддержка: 10
# {'Label:BENIGN', 'Protocol:17', 'Destination Port:53', 'Flow Duration:321'} поддержка: 10
# {'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:349', 'Protocol:17'} поддержка: 10
# {'Label:BENIGN', 'Protocol:17', 'Destination Port:53', 'Flow Duration:352'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:131'} поддержка: 10
# {'Protocol:6', 'Destination Port:443', 'Label:BENIGN', 'Total Fwd Packets:63'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:1', 'Destination Port:49666'} поддержка: 10
# {'Protocol:6', 'Flow Duration:103', 'Label:BENIGN', 'Total Fwd Packets:1'} поддержка: 10
# {'Protocol:6', 'Destination Port:443', 'Label:BENIGN', 'Flow Duration:126'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:111'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:1', 'Flow Duration:114'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:320'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:316'} поддержка: 10
# {'Flow Duration:133', 'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:1'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:1', 'Flow Duration:124'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:124'} поддержка: 10
# {'Protocol:6', 'Flow Duration:104', 'Label:BENIGN', 'Total Fwd Packets:2'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:101'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:38', 'Destination Port:80'} поддержка: 10
# {'Protocol:6', 'Destination Port:443', 'Label:BENIGN', 'Flow Duration:136'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Destination Port:80', 'Total Fwd Packets:34'} поддержка: 10
# {'Flow Duration:272', 'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:2'} поддержка: 10
# {'Flow Duration:68', 'Total Fwd Packets:2', 'Label:BENIGN', 'Protocol:6'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:46'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:1', 'Flow Duration:143'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:3', 'Flow Duration:66'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:242'} поддержка: 10
# {'Protocol:6', 'Flow Duration:257', 'Label:BENIGN', 'Total Fwd Packets:2'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:220'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:241'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:221'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:51'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:237'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:39', 'Destination Port:80'} поддержка: 10
# {'Protocol:6', 'Flow Duration:154', 'Label:BENIGN', 'Total Fwd Packets:2'} поддержка: 10
# {'Protocol:6', 'Flow Duration:53', 'Label:BENIGN', 'Total Fwd Packets:2'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:236'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:172'} поддержка: 10
# {'Flow Duration:178', 'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:2'} поддержка: 10
# {'Protocol:6', 'Flow Duration:190', 'Label:BENIGN', 'Total Fwd Packets:2'} поддержка: 10
# {'Protocol:6', 'Flow Duration:199', 'Label:BENIGN', 'Total Fwd Packets:2'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:205'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:188'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:2', 'Label:BENIGN', 'Flow Duration:198'} поддержка: 10
# {'Destination Port:21', 'Total Fwd Packets:2', 'Label:BENIGN', 'Protocol:6'} поддержка: 10
# {'Protocol:6', 'Flow Duration:196', 'Label:BENIGN', 'Total Fwd Packets:2'} поддержка: 10
# {'Protocol:6', 'Total Fwd Packets:2', 'Destination Port:80', 'Flow Duration:77'} поддержка: 10
# {'Flow Duration:307', 'Label:BENIGN', 'Total Fwd Packets:2', 'Destination Port:53', 'Protocol:17'} поддержка: 10
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Destination Port:53', 'Protocol:17', 'Flow Duration:339'} поддержка: 10
# {'Flow Duration:347', 'Label:BENIGN', 'Total Fwd Packets:2', 'Destination Port:53', 'Protocol:17'} поддержка: 10
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Destination Port:53', 'Flow Duration:323', 'Protocol:17'} поддержка: 10
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:318', 'Destination Port:53', 'Protocol:17'} поддержка: 10
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:315', 'Destination Port:53', 'Protocol:17'} поддержка: 10
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:316', 'Destination Port:53', 'Protocol:17'} поддержка: 10
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:124', 'Destination Port:53', 'Protocol:17'} поддержка: 10
# {'Total Fwd Packets:13', 'Label:BENIGN', 'Destination Port:138', 'Flow Duration:25', 'Protocol:17'} поддержка: 10
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:94', 'Protocol:6', 'Destination Port:80'} поддержка: 10
# {'Protocol:6', 'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:73', 'Destination Port:80'} поддержка: 10
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:88', 'Protocol:6', 'Destination Port:80'} поддержка: 10
# {'Destination Port:443', 'Label:BENIGN', 'Total Fwd Packets:2', 'Protocol:6', 'Flow Duration:145'} поддержка: 10
# {'Label:BENIGN', 'Total Fwd Packets:2', 'Protocol:6', 'Flow Duration:65', 'Destination Port:80'} поддержка: 10
# {'Destination Port:443', 'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:158', 'Protocol:6'} поддержка: 10
# {'Destination Port:443', 'Label:BENIGN', 'Total Fwd Packets:2', 'Flow Duration:175', 'Protocol:6'} поддержка: 10
# {'Label:BENIGN', 'Destination Port:465', 'Total Fwd Packets:2', 'Flow Duration:3', 'Protocol:6'} поддержка: 10
# {'Destination Port:21', 'Label:BENIGN', 'Protocol:6', 'Flow Duration:49', 'Total Fwd Packets:1'} поддержка: 10
